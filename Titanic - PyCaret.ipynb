# %%
# Import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import os
import seaborn as sns
os.chdir("P:\\Courses\\Kaggle\\Titanic\\Data")

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
from pycaret.classification import *
 
titanic_train=setup(train, target = 'Survived')
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_0ed03d58_f254_11ea_bf71_3cf862c4a125row4_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_0ed03d58_f254_11ea_bf71_3cf862c4a125" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0ed03d58_f254_11ea_bf71_3cf862c4a125level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0ed03d58_f254_11ea_bf71_3cf862c4a125row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_0ed03d58_f254_11ea_bf71_3cf862c4a125row0_col1" class="data row0 col1" >3854</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed03d58_f254_11ea_bf71_3cf862c4a125level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
xgboost = create_model('xgboost', max_depth = 10)
# Out:
# <style  type="text/css" >
#     #T_68ab642c_f254_11ea_9258_3cf862c4a125row10_col0 {
#             background:  yellow;
#         }    #T_68ab642c_f254_11ea_9258_3cf862c4a125row10_col1 {
#             background:  yellow;
#         }    #T_68ab642c_f254_11ea_9258_3cf862c4a125row10_col2 {
#             background:  yellow;
#         }    #T_68ab642c_f254_11ea_9258_3cf862c4a125row10_col3 {
#             background:  yellow;
#         }    #T_68ab642c_f254_11ea_9258_3cf862c4a125row10_col4 {
#             background:  yellow;
#         }    #T_68ab642c_f254_11ea_9258_3cf862c4a125row10_col5 {
#             background:  yellow;
#         }    #T_68ab642c_f254_11ea_9258_3cf862c4a125row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(xgboost)

# %%
plot_model(xgboost, plot='feature')

# %%
ada = create_model('ada')
# Out:
# <style  type="text/css" >
#     #T_5f92137a_f256_11ea_ba46_3cf862c4a125row10_col0 {
#             background:  yellow;
#         }    #T_5f92137a_f256_11ea_ba46_3cf862c4a125row10_col1 {
#             background:  yellow;
#         }    #T_5f92137a_f256_11ea_ba46_3cf862c4a125row10_col2 {
#             background:  yellow;
#         }    #T_5f92137a_f256_11ea_ba46_3cf862c4a125row10_col3 {
#             background:  yellow;
#         }    #T_5f92137a_f256_11ea_ba46_3cf862c4a125row10_col4 {
#             background:  yellow;
#         }    #T_5f92137a_f256_11ea_ba46_3cf862c4a125row10_col5 {
#             background:  yellow;
#         }    #T_5f92137a_f256_11ea_ba46_3cf862c4a125row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(ada)

# %%
ada_pred = predict_model(ada, data = test)

# %%
ada_pred.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Label   Score
# 0  34.5      0      0   330911   7.8292   NaN        Q      0  0.4833
# 1  47.0      1      0   363272   7.0000   NaN        S      1  0.5052
# 2  62.0      0      0   240276   9.6875   NaN        Q      0  0.4855
# 3  27.0      0      0   315154   8.6625   NaN        S      0  0.4827
# 4  22.0      1      1  3101298  12.2875   NaN        S      1  0.5023

# %%
xgb_pred = predict_model(xgboost, data = test)

# %%
ada_pred.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Label   Score
# 0  34.5      0      0   330911   7.8292   NaN        Q      0  0.4833
# 1  47.0      1      0   363272   7.0000   NaN        S      1  0.5052
# 2  62.0      0      0   240276   9.6875   NaN        Q      0  0.4855
# 3  27.0      0      0   315154   8.6625   NaN        S      0  0.4827
# 4  22.0      1      1  3101298  12.2875   NaN        S      1  0.5023

# %%
evaluate_model(xgboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(ada)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
ada_pred.to_csv('ada_results.csv')
xgb_pred.to_csv('xgb_results.csv')
